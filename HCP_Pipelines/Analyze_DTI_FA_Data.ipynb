# %%
import nipype
import os,glob,sys,shutil
import nipype.interfaces.fsl as fsl
import nipype.pipeline.engine as pe
import nipype.interfaces.utility as util
import nipype.interfaces.io as nio
from IPython.display import Image

# %%
# subjRootDir = "/data/HCP_BedpostData/"
# FULL_SUBJECT_LIST = [x for x in os.listdir(subjRootDir) if os.path.isdir( subjRootDir+x)]
# print(len(FULL_SUBJECT_LIST),"Subjects are potentially available to be processed!")
# Out:
# 899 Subjects are potentially available to be processed!

# %%
nipype_DTIFITdir = '/data/NipypeScratch/gen_fa.old'

dtiFIT_subjList = [x.replace('_subject_id_','') for x in os.listdir(nipype_DTIFITdir) if os.path.isdir(nipype_DTIFITdir+'/'+x)]

subjFADict = {}

for s in dtiFIT_subjList:
    FA_file = os.path.join(nipype_DTIFITdir,"_subject_id_%s"%s,'dtifit',"%s_FA.nii.gz"% s)
#     print(FA_file)
    if os.path.isfile(FA_file):qls
        subjFADict[s] = FA_file

# %%
print(len(subjFADict.keys() ))


volStats = fsl.ImageStats()

sampleSubj = list(subjFADict.keys())[0]


volStats.inputs.in_file = subjFADict[ sampleSubj ]
volStats.inputs.op_string = ' -M -c'
res = volStats.run()
# Out:
# 804
# 180730-18:53:18,203 interface INFO:
# 	 stdout 2018-07-30T18:53:18.203420:0.262189 -0.631041 -23.648393 7.553515

# %%
res.outputs
# Out:
# out_stat = [0.262189, -0.631041, -23.648393, 7.553515]

# %%
# # """
# # Setup for DataGrabber inputs needed for probtrackx2
# # """
# datasource = nio.DataGrabber(outfields=['nodif_brain_mask','xfm','invxfm','thsamples','phsamples','fsamples'])
# # create a node to obtain the functional images
# datasource.inputs.base_directory = "/data/HCP_BedpostData/"
# datasource.inputs.template ='*'
# datasource.inputs.sort_filelist = True
# datasource.inputs.field_template = dict(
#     thsamples='%s/T1w/Diffusion.bedpostX/merged_%s.nii*',
#     fsamples='%s/T1w/Diffusion.bedpostX/merged_%s.nii*',
#     phsamples='%s/T1w/Diffusion.bedpostX/merged_%s.nii*',
#     nodif_brain_mask='%s/T1w/Diffusion.bedpostX/%s.nii*', 
#     xfm='%s/MNINonLinear/xfms/%s.nii*',
#     invxfm='%s/MNINonLinear/xfms/%s.nii*',
    
#     )

# datasource.inputs.template_args = dict(
#              thsamples = [['subject_id','th1samples']],
#              phsamples =  [['subject_id','ph1samples']],
#              fsamples =  [['subject_id','f1samples']],
#              nodif_brain_mask = [['subject_id','nodif_brain_mask']],
#              xfm = [['subject_id','acpc_dc2standard']],
#              invxfm = [['subject_id', 'standard2acpc_dc']]           
#         )

# %%
# datasource.inputs.raise_on_empty = False

# completeSubjs = []
# missingSubjs = []
# for s in FULL_SUBJECT_LIST:
#     datasource.inputs.subject_id = s
#     results = datasource.run()

#     if None not in results.outputs.get().values():
#         completeSubjs.append(s)
#     else:
#         missingSubjs.append(s)
# Out:
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/144832/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/144832/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/144832/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/146432/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/146432/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/146432/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/146533/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/146533/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/146533/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/146634/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/146634/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/146634/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/148032/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/148032/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/148032/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/148032/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/148133/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/148133/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/148133/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/148133/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/148941/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/148941/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/148941/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/148941/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/149337/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/149337/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/149337/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/149741/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/149741/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/149741/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/149741/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/151526/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/151526/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/151526/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/153429/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/153429/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/153429/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/175540/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/175540/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/175540/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/195849/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/195849/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/195849/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/195849/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/195950/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/195950/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/195950/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/195950/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/196346/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/196346/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/196346/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/196346/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/198249/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/198249/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/198249/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/198249/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/227432/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/227432/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/227432/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/512835/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/512835/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/512835/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/512835/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/522434/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/522434/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/522434/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/522434/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/541943/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/541943/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/541943/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/541943/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/555651/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/555651/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/555651/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/555651/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/580044/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/580044/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/580044/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/580044/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/581450/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/581450/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/581450/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/581450/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/901038/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/901038/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/901038/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/901038/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/910241/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/910241/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/910241/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/910241/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/965771/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/965771/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/965771/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/965771/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/978578/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/978578/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/978578/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/978578/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/979984/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/979984/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/979984/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/979984/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/984472/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/984472/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/984472/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/984472/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/987983/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/987983/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/987983/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/987983/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/990366/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/990366/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/990366/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/990366/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/992673/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/992673/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/992673/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/992673/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/106521/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/106521/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/106521/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/106521/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/107220/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/107220/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/107220/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/107220/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/109123/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/109123/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/109123/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/109123/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/110411/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/110411/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/110411/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/110411/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/111716/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/111716/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/111716/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/111716/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/113821/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/113821/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/113821/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/113821/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/113922/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/113922/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/113922/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/113922/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/116120/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/116120/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/116120/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/116120/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/120212/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/120212/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/120212/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/120212/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/121719/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/121719/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/121719/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/121719/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/121820/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/121820/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/121820/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/121820/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/122317/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/122317/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/122317/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/122317/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/123117/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/123117/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/123117/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/123117/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/124826/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/124826/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/124826/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/124826/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/207628/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/207628/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/207628/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/207628/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: xfm Template: /data/HCP_BedpostData/207628/MNINonLinear/xfms/acpc_dc2standard.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: invxfm Template: /data/HCP_BedpostData/207628/MNINonLinear/xfms/standard2acpc_dc.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/559053/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/559053/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/559053/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/559053/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/562446/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/562446/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/562446/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/562446/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/567961/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/567961/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/567961/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/567961/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/579867/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/579867/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/579867/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/579867/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/613235/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/613235/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/613235/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/613235/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/733548/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/733548/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/733548/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/733548/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/745555/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/745555/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/745555/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/745555/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: xfm Template: /data/HCP_BedpostData/745555/MNINonLinear/xfms/acpc_dc2standard.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: invxfm Template: /data/HCP_BedpostData/745555/MNINonLinear/xfms/standard2acpc_dc.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/145834/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/145834/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/145834/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/146331/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/146331/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/146331/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/145127/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# ...
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/108323/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/108323/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/108323/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/114419/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/114419/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/114419/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/114419/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/119833/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/119833/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/119833/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/119833/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/121618/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/121618/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/121618/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/121618/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/126325/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/126325/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/126325/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/126325/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/126628/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/126628/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/126628/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/126628/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/127630/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/127630/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/127630/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/127630/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/128632/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/128632/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/128632/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/128632/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/168038/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/168038/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/168038/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/168038/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/197449/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/197449/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/197449/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/197449/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: xfm Template: /data/HCP_BedpostData/197449/MNINonLinear/xfms/acpc_dc2standard.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: invxfm Template: /data/HCP_BedpostData/197449/MNINonLinear/xfms/standard2acpc_dc.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/317332/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/317332/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/317332/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/317332/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/485757/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/485757/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/485757/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/485757/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/570243/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/570243/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/570243/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/570243/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/580751/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/580751/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/580751/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/580751/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/611231/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/611231/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/611231/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/611231/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: xfm Template: /data/HCP_BedpostData/611231/MNINonLinear/xfms/acpc_dc2standard.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: invxfm Template: /data/HCP_BedpostData/611231/MNINonLinear/xfms/standard2acpc_dc.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/650746/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/650746/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/650746/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/650746/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: xfm Template: /data/HCP_BedpostData/650746/MNINonLinear/xfms/acpc_dc2standard.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: invxfm Template: /data/HCP_BedpostData/650746/MNINonLinear/xfms/standard2acpc_dc.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/662551/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/662551/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/662551/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /opt/conda/lib/python3.6/site-packages/nipype/interfaces/io.py:1239: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/662551/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)

# %%
# print("Found %d complete subjs and %d were missing some data elements" % (len(completeSubjs),len(missingSubjs)))
# Out:
# Found 656 complete subjs and 243 were missing some data elements

# %%
# """
# Setup for Probtrackx2 Computational Pipeline
# """
# subj_infosource = pe.Node(interface=util.IdentityInterface(fields=['subject_id']),  name="subj_infosource")
# #infosource.iterables = ('subject_id', SampleSubjList)
# subj_infosource.iterables = ('subject_id', completeSubjs)
# ### Above just converts the list of subjects into an iterable list I can connect to the next part of the pipeline

# %%
# # """
# # Setup for DataGrabber inputs needed for probtrackx2
# # """
# datasource = pe.Node(interface=nio.DataGrabber(infields=['subject_id'],
#         outfields=['nodif_brain_mask','xfm','invxfm','thsamples','phsamples','fsamples']),
#         name='datasource')
# # create a node to obtain the functional images
# datasource.inputs.base_directory = "/data/HCP_BedpostData/"
# datasource.inputs.template ='*'
# datasource.inputs.sort_filelist = True
# datasource.inputs.field_template = dict(
#     thsamples='%s/T1w/Diffusion.bedpostX/merged_%s.nii*',
#     fsamples='%s/T1w/Diffusion.bedpostX/merged_%s.nii*',
#     phsamples='%s/T1w/Diffusion.bedpostX/merged_%s.nii*',
#     nodif_brain_mask='%s/T1w/Diffusion.bedpostX/%s.nii*', 
#     xfm='%s/MNINonLinear/xfms/%s.nii*',
#     invxfm='%s/MNINonLinear/xfms/%s.nii*'
#     )

# datasource.inputs.template_args = dict(
#              thsamples = [['subject_id','th1samples']],
#              phsamples =  [['subject_id','ph1samples']],
#              fsamples =  [['subject_id','f1samples']],
#              nodif_brain_mask = [['subject_id','nodif_brain_mask']],
#              xfm = [['subject_id','acpc_dc2standard']],
#              invxfm = [['subject_id', 'standard2acpc_dc']]           
#         )

# %%
# seedMask = "/data/EHECHT_ROIS/Human_Hypothalamus_Bilat.nii.gz"
# seedMaskList = glob.glob('/data/EHECHT_ROIS/Hu*')
# debug_output = False

# if debug_output:
#     pbx2 = fsl.ProbTrackX2()
#     pbx2.inputs.thsamples=subjRootDir+SampleSubjList[0]+'/T1w/Diffusion.bedpostX/merged_th1samples.nii.gz'
#     pbx2.inputs.phsamples=subjRootDir+SampleSubjList[0]+'/T1w/Diffusion.bedpostX/merged_ph1samples.nii.gz'
#     pbx2.inputs.fsamples=subjRootDir+SampleSubjList[0]+'/T1w/Diffusion.bedpostX/merged_f1samples.nii.gz'
#     pbx2.inputs.mask = subjRootDir+SampleSubjList[0]+'/T1w/Diffusion.bedpostX/nodif_brain_mask.nii.gz'
#     pbx2.inputs.samples_base_name = subjRootDir+SampleSubjList[0]+'/T1w/Diffusion.bedpostX/merged'
# else:
#     pbx2 = pe.Node(interface=fsl.ProbTrackX2(), name='pbx2')

    
# pbx2.inputs.c_thresh = 0.2   # -c 0.2   F cutoff
# pbx2.inputs.n_steps = 2000   # -S 2000
# pbx2.inputs.step_length = 0.5 # --steplength=0.5
# pbx2.inputs.n_samples = 25000  # -P 5000
# pbx2.inputs.opd = True
# pbx2.inputs.loop_check = True
# # pbx2.inputs.fibst = True

# pbx2.iterables = ("seed", seedMaskList)

# # pbx2.inputs.onewaycondition = True # --onewaycondition
# pbx2.inputs.correct_path_distribution = True # -pd  i.e. distance correction
# #pbx2.inputs.lrtarget3= targetMask  ## This is a hack for now
# pbx2.inputs.seed = seedMask
# #pbx2.inputs.omatrix3 = True   # --omatrix3
# #pbx2.inputs.target3 = targetMask # --target3=$WORKINGDATAPATH/All_Foxes_FA_to_Unselected-Template_GM.nii.gz "; 

# ### #FIBTHRESH APPEARS MISSING FROM INTERFACE???
# if debug_output:
#     print( pbx2.cmdline)
#     print("WE WILL BE PROCESSING THE FOLLOWING ROIS")
#     print([os.path.basename(x) for x in seedMaskList])
#     pbx2.inputs.os2t = True

# %%
probtrackx2  --fibthresh=0.1 --randfib=0

# %%
# !source /usr/share/fsl/5.0/etc/fslconf/fsl.sh

# %%
# !which probtrackx2_gpu
# Out:
# /usr/lib/fsl/5.0/probtrackx2_gpu

# %%
# #runpbx.connect(subj_infosource,'subject_id',datasource,'subject_id')
# runpbx2  = pe.Workflow(name="runpbx2_gpu")
# runpbx2.base_dir = "/data/NipypeScratch/"

# samples_base_name_fxn = lambda x : x.replace('_th1samples.nii.gz','')


# runpbx2.connect(subj_infosource,'subject_id',datasource,'subject_id')
# # ### Connect the dti_datasource to the pbx2 command
# runpbx2.connect( datasource,'thsamples',pbx2,'thsamples')
# runpbx2.connect( datasource,'phsamples',pbx2,'phsamples')
# runpbx2.connect( datasource,'fsamples',pbx2,'fsamples')
# runpbx2.connect( datasource,'nodif_brain_mask',pbx2,'mask')
# runpbx2.connect( datasource, ('thsamples', samples_base_name_fxn ), pbx2,'samples_base_name') ###  NOTE THIS IS A WEIRD TUPLE IS

# # runpbx2.run()
# runpbx2.run(plugin='MultiProc', plugin_args={'n_procs' : 1})

# %%
### Each probtrackx command for the HCP data set was using about 2% of the memory.. it varied from 1.4 --> 2.3

### So on this machine, we could probably specify 36 threads... even 40 although that may start getting dicey

# %%
### Write a data validator that makes sure everything in the datasource actually exists...

# %%
# runpbx2.connect( dti_datasource, ('thsamples',samples_base_name_fxn) ,pbx2,'samples_base_name')
# # Run tractography with warp to/from template space
# $statement .= " -s $WORKINGDATAPATH/Fox_" . $subj[$k] . "/data.bedpostX/merged "; 
# $statement .= " -x $WORKINGDATAPATH/All_Foxes_FA_to_Unselected-Template_WM.nii.gz ";  ## check downsample
# $statement .= " -l   --fibthresh=0.1 --randfib=0 ";  ## check # of samples
# $statement .= " --forcedir --opd ";
# $statement .= " --dir=$WORKINGDATAPATH/Fox_" . $subj[$k] . "/data.bedpostX/WholeBrainMatrixConnectivity_TemplateSpace_fullres/ ";
# print "$statement \n";

# %%
print(gen_fa.write_graph(graph2use='colored',simple_form=False))
Image('/data/HCP_Data/NipypeScratch/gen_fa/graph.png')
#Image('/data/HCP_Data/NipypeScratch/gen_fa/graph.png')

# %%
gen_fa.run(plugin='MultiProc', plugin_args={'n_procs' : 20})

# %%
#!ls /data/HCP_Data/HCP_BedpostData/106016/T1w/Diffusion/

# %%
datasink = pe.Node(interface=nio.DataSink(), name="datasink")
datasink.inputs.base_directory = os.path.join(os.path.abspath(working_data_dir),
                                              'sri_results')
datasink.inputs.parameterization = False
gen_fa.connect(dtifit, 'FA', datasink, 'FA')
gen_fa.connect(dtifit, 'MD', datasink, 'MD')

# %%
from nipype.interfaces import fsl

subjDir = "/data/HCP_Data/HCP_BedpostData/100206/T1w/Diffusion.bedpostX/"

pbx2 = fsl.ProbTrackX2()
pbx2.inputs.seed = '/data/HCP_Data/EHECHT_ROIS/Human_BasalForebrain_Left.nii.gz'
pbx2.inputs.thsamples = subjDir + 'merged_th1samples.nii.gz'
pbx2.inputs.fsamples =  subjDir + 'merged_f1samples.nii.gz'
pbx2.inputs.phsamples =  subjDir + 'merged_ph1samples.nii.gz'
pbx2.inputs.mask =  subjDir + 'nodif_brain_mask.nii.gz'
pbx2.inputs.out_dir = '.'
pbx2.inputs.n_samples = 3
pbx2.inputs.n_steps = 10
pbx2.cmdline
pbx2.run()
#'probtrackx2 --forcedir -m nodif_brain_mask.nii.gz --nsamples=3 --nstep
