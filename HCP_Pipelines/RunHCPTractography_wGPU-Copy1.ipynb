# %%
import nipype
import os,glob,sys,shutil
import nipype.interfaces.fsl as fsl
import nipype.pipeline.engine as pe
import nipype.interfaces.utility as util
import nipype.interfaces.io as nio
from IPython.display import Image

# %%
subjRootDir = "/data/HCP_BedpostData/"
FULL_SUBJECT_LIST = [x for x in os.listdir(subjRootDir) if os.path.isdir( subjRootDir+x)]
print(len(FULL_SUBJECT_LIST),"Subjects are potentially available to be processed!")
# Out:
# (900, 'Subjects are potentially available to be processed!')

# %%
    
# """
# Setup for DataGrabber inputs needed for probtrackx2
# """
datasource = nio.DataGrabber(outfields=['nodif_brain_mask','xfm','invxfm','thsamples','phsamples','fsamples','mniROIs'])
# create a node to obtain the functional images
datasource.inputs.base_directory = "/data/HCP_BedpostData/"
datasource.inputs.template ='*'
datasource.inputs.sort_filelist = True
datasource.inputs.field_template = dict(
    thsamples='%s/T1w/Diffusion.bedpostX/merged_%s.nii*',
    fsamples='%s/T1w/Diffusion.bedpostX/merged_%s.nii*',
    phsamples='%s/T1w/Diffusion.bedpostX/merged_%s.nii*',
    nodif_brain_mask='%s/T1w/Diffusion.bedpostX/%s.nii*', 
    xfm='%s/MNINonLinear/xfms/%s.nii*',
    invxfm='%s/MNINonLinear/xfms/%s.nii*',
    mniROIs='addlInfo/subjContainer/%s/DTI_ROIs/*'
    )

datasource.inputs.template_args = dict(
             thsamples = [['subject_id','th1samples']],
             phsamples =  [['subject_id','ph1samples']],
             fsamples =  [['subject_id','f1samples']],
             nodif_brain_mask = [['subject_id','nodif_brain_mask']],
             xfm = [['subject_id','acpc_dc2standard']],
             invxfm = [['subject_id', 'standard2acpc_dc']],
            mniROIs=[['subject_id']]
        )

# %%
datasource.inputs.raise_on_empty = False

completeSubjs = []
missingSubjs = []
for s in FULL_SUBJECT_LIST:
    datasource.inputs.subject_id = s
    results = datasource.run()

    if None not in results.outputs.get().values():
        completeSubjs.append(s)
    else:
        missingSubjs.append(s)
# Out:
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/101006/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/101410/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/102513/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/103111/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/106016/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/112516/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/122822/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/123521/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/124624/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/127327/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/128026/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/129129/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/130821/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/132118/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/133019/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/134324/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/135730/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/137128/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/138231/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/144428/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/144832/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/146432/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/146533/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/146634/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/148032/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/148133/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/148941/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/149337/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/149741/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/150019/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/150524/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/151425/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/151526/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/151829/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/152831/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/153429/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/153732/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/154229/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/154734/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/154835/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/156334/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/157437/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/157942/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/158540/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/159138/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/159340/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/163432/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/164030/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/164131/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/165032/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/165638/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/165840/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/169343/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/169747/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/169949/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/172029/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/172433/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/173435/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/173940/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/175237/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/175338/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/175540/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/176037/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/176542/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/178243/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/178748/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/181131/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/182436/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/182840/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/185139/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/185947/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/187345/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/188549/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/189450/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/191033/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/191437/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/193239/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/194746/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/195849/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/195849/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/195849/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/195849/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/195849/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/195950/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/195950/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/195950/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/195950/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/195950/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/196346/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/196346/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/196346/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/196346/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/196346/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/198249/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/198249/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/198249/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/198249/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/198249/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/204016/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/204319/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/204622/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/205220/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/208327/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/209127/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/209228/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/210011/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/211316/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/211922/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/212823/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/214019/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/214625/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/220721/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/227432/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/227432/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/227432/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/227432/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/231928/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/237334/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/245333/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/248339/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/257542/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/268749/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/268850/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/293748/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/303119/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/304020/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/304727/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/307127/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/308331/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/309636/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/316835/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/320826/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/322224/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/329440/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/336841/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/339847/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/348545/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/353740/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/355239/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/361234/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/361941/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/365343/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/366446/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/379657/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/381543/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/395251/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/397861/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/406432/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/424939/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/433839/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/456346/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/512835/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/512835/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/512835/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/512835/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/512835/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/522434/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/522434/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/522434/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/522434/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/522434/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/541943/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/541943/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/541943/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/541943/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/541943/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/555651/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/555651/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/555651/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/555651/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/555651/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/580044/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/580044/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/580044/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/580044/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/580044/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/581450/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/581450/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/581450/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/581450/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/581450/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/601127/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/611938/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/613538/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/614439/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/616645/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/647858/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/654350/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/656253/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/656657/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/668361/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/672756/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/677968/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/680250/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/680957/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/695768/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/704238/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/709551/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/713239/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/715041/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/720337/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/724446/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/725751/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/732243/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/734045/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/735148/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/749361/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/751550/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/753251/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/767464/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/773257/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/779370/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/786569/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/792766/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/803240/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/837560/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/856463/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/856766/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/859671/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/872158/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/877168/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/880157/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/887373/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/891667/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/899885/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/901038/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/901038/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/901038/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/901038/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/901038/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# ...
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/121618/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/121618/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/126325/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/126325/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/126325/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/126325/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/126325/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/126628/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/126628/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/126628/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/126628/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/126628/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/127630/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/127630/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/127630/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/127630/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/127630/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/128632/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/128632/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/128632/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/128632/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/128632/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/168038/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/168038/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/168038/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/168038/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/168038/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/197449/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/197449/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: xfm Template: /data/HCP_BedpostData/197449/MNINonLinear/xfms/acpc_dc2standard.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: invxfm Template: /data/HCP_BedpostData/197449/MNINonLinear/xfms/standard2acpc_dc.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/197449/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/197449/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/197449/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/317332/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/317332/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/317332/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/317332/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/317332/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/485757/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/485757/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/485757/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/485757/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/485757/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/570243/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/570243/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/570243/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/570243/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/570243/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/580751/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/580751/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/580751/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/580751/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/580751/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/611231/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/611231/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: xfm Template: /data/HCP_BedpostData/611231/MNINonLinear/xfms/acpc_dc2standard.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: invxfm Template: /data/HCP_BedpostData/611231/MNINonLinear/xfms/standard2acpc_dc.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/611231/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/611231/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/611231/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/650746/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/650746/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: xfm Template: /data/HCP_BedpostData/650746/MNINonLinear/xfms/acpc_dc2standard.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: invxfm Template: /data/HCP_BedpostData/650746/MNINonLinear/xfms/standard2acpc_dc.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/650746/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/650746/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/650746/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: phsamples Template: /data/HCP_BedpostData/662551/T1w/Diffusion.bedpostX/merged_ph1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: fsamples Template: /data/HCP_BedpostData/662551/T1w/Diffusion.bedpostX/merged_f1samples.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: mniROIs Template: /data/HCP_BedpostData/addlInfo/subjContainer/662551/DTI_ROIs/* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: nodif_brain_mask Template: /data/HCP_BedpostData/662551/T1w/Diffusion.bedpostX/nodif_brain_mask.nii* returned no files
#   warn(msg)
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py:1236: UserWarning: Output key: thsamples Template: /data/HCP_BedpostData/662551/T1w/Diffusion.bedpostX/merged_th1samples.nii* returned no files
#   warn(msg)

# %%
print("Found %d complete subjs and %d were missing some data elements" % (len(completeSubjs),len(missingSubjs)))
# Out:
# Found 405 complete subjs and 495 were missing some data elements

# %%
"""
Setup for Probtrackx2 Computational Pipeline
"""
subj_infosource = pe.Node(interface=util.IdentityInterface(fields=['subject_id']),  name="subj_infosource")
#infosource.iterables = ('subject_id', SampleSubjList)
subj_infosource.iterables = ('subject_id', completeSubjs)
### Above just converts the list of subjects into an iterable list I can connect to the next part of the pipeline

# %%
# """
# Setup for DataGrabber inputs needed for probtrackx2
# """
datasource = pe.Node(interface=nio.DataGrabber(infields=['subject_id'],
        outfields=['nodif_brain_mask','xfm','invxfm','thsamples','phsamples','fsamples','mniROIs']),
        name='datasource')
# create a node to obtain the functional images
datasource.inputs.base_directory = "/data/HCP_BedpostData/"
datasource.inputs.template ='*'
datasource.inputs.sort_filelist = True
datasource.inputs.field_template = dict(
    thsamples='%s/T1w/Diffusion.bedpostX/merged_%s.nii*',
    fsamples='%s/T1w/Diffusion.bedpostX/merged_%s.nii*',
    phsamples='%s/T1w/Diffusion.bedpostX/merged_%s.nii*',
    nodif_brain_mask='%s/T1w/Diffusion.bedpostX/%s.nii*', 
    xfm='%s/MNINonLinear/xfms/%s.nii*',
    invxfm='%s/MNINonLinear/xfms/%s.nii*',
    mniROIs='addlInfo/subjContainer/%s/DTI_ROIs/*'
    )

datasource.inputs.template_args = dict(
             thsamples = [['subject_id','th1samples']],
             phsamples =  [['subject_id','ph1samples']],
             fsamples =  [['subject_id','f1samples']],
             nodif_brain_mask = [['subject_id','nodif_brain_mask']],
             xfm = [['subject_id','acpc_dc2standard']],
             invxfm = [['subject_id', 'standard2acpc_dc']],
            mniROIs = [['subject_id']]
        )

# %%
seedMask = "/data/EHECHT_ROIS/Human_Hypothalamus_Bilat.nii.gz"
#seedMaskList = glob.glob('/data/EHECHT_ROIS/Hu*')
debug_output = False

if debug_output:
    pbx2 = fsl.ProbTrackX2(iterfield=['seed'])
    pbx2.inputs.thsamples=subjRootDir+SampleSubjList[0]+'/T1w/Diffusion.bedpostX/merged_th1samples.nii.gz'
    pbx2.inputs.phsamples=subjRootDir+SampleSubjList[0]+'/T1w/Diffusion.bedpostX/merged_ph1samples.nii.gz'
    pbx2.inputs.fsamples=subjRootDir+SampleSubjList[0]+'/T1w/Diffusion.bedpostX/merged_f1samples.nii.gz'
    pbx2.inputs.mask = subjRootDir+SampleSubjList[0]+'/T1w/Diffusion.bedpostX/nodif_brain_mask.nii.gz'
    pbx2.inputs.samples_base_name = subjRootDir+SampleSubjList[0]+'/T1w/Diffusion.bedpostX/merged'
else:
    pbx2 = pe.Node(interface=fsl.ProbTrackX2(), name='pbx2')

    
pbx2.inputs.c_thresh = 0.2   # -c 0.2   F cutoff
pbx2.inputs.n_steps = 2000   # -S 2000
pbx2.inputs.step_length = 0.5 # --steplength=0.5
pbx2.inputs.n_samples = 25000  # -P 5000
pbx2.inputs.opd = True
pbx2.inputs.loop_check = True
# pbx2.inputs.fibst = True

#pbx2.iterables = ("seed", seedMaskList)

# pbx2.inputs.onewaycondition = True # --onewaycondition
pbx2.inputs.correct_path_distribution = True # -pd  i.e. distance correction
#pbx2.inputs.lrtarget3= targetMask  ## This is a hack for now
pbx2.inputs.seed = seedMask
#pbx2.inputs.omatrix3 = True   # --omatrix3
#pbx2.inputs.target3 = targetMask # --target3=$WORKINGDATAPATH/All_Foxes_FA_to_Unselected-Template_GM.nii.gz "; 

### #FIBTHRESH APPEARS MISSING FROM INTERFACE???
if debug_output:
    print( pbx2.cmdline)
    print("WE WILL BE PROCESSING THE FOLLOWING ROIS")
    print([os.path.basename(x) for x in seedMaskList])
    pbx2.inputs.os2t = True

# %%
#runpbx.connect(subj_infosource,'subject_id',datasource,'subject_id')
runpbx2  = pe.Workflow(name="runpbx2_gpu_dtispace")
runpbx2.base_dir = "/data/NipypeScratch/"

samples_base_name_fxn = lambda x : x.replace('_th1samples.nii.gz','')


runpbx2.connect(subj_infosource,'subject_id',datasource,'subject_id')
# ### Connect the dti_datasource to the pbx2 command
runpbx2.connect( datasource,'thsamples',pbx2,'thsamples')
runpbx2.connect( datasource,'phsamples',pbx2,'phsamples')
runpbx2.connect( datasource,'fsamples',pbx2,'fsamples')
runpbx2.connect( datasource,'nodif_brain_mask',pbx2,'mask')
runpbx2.connect( datasource, ('thsamples', samples_base_name_fxn ), pbx2,'samples_base_name') ###  NOTE THIS IS A WEIRD TUPLE IS
runpbx2.connect( datasource,'mniROIs', pbx2,'seed')
#runpbx2.run()
#runpbx2.write_graph()

runpbx2.run(plugin='MultiProc', plugin_args={'n_procs' : 1})
# Out:
# 180824-17:50:43,912 nipype.workflow INFO:
# 	 Workflow runpbx2_gpu_dtispace settings: ['check', 'execution', 'logging', 'monitoring']
# 180824-17:50:51,967 nipype.workflow INFO:
# 	 Running in parallel.
# 180824-17:50:52,3 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 405 jobs ready. Free memory (GB): 169.98/169.98, Free processors: 1/1.
# 180824-17:50:52,124 nipype.workflow INFO:
# 	 [Node] Setting-up "runpbx2_gpu_dtispace.datasource" in "/data/NipypeScratch/runpbx2_gpu_dtispace/_subject_id_727553/datasource".
# 180824-17:50:52,409 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
# 180824-17:50:52,435 nipype.workflow INFO:
# 	 [Node] Finished "runpbx2_gpu_dtispace.datasource".
# 180824-17:50:54,5 nipype.workflow INFO:
# 	 [Job 0] Completed (runpbx2_gpu_dtispace.datasource).
# 180824-17:50:54,17 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 405 jobs ready. Free memory (GB): 169.98/169.98, Free processors: 1/1.
# 180824-17:50:54,710 nipype.workflow INFO:
# 	 [Node] Setting-up "runpbx2_gpu_dtispace.pbx2" in "/data/NipypeScratch/runpbx2_gpu_dtispace/_subject_id_727553/pbx2".
# 180824-17:50:55,268 nipype.workflow INFO:
# 	 [Node] Running "pbx2" ("nipype.interfaces.fsl.dti.ProbTrackX2"), a CommandLine Interface with command:
# probtrackx2 --cthr=0.200 --pd --forcedir --loopcheck -m /data/HCP_BedpostData/727553/T1w/Diffusion.bedpostX/nodif_brain_mask.nii.gz --nsamples=25000 --nsteps=2000 --opd --dir=/data/NipypeScratch/runpbx2_gpu_dtispace/_subject_id_727553/pbx2 --samples=/data/HCP_BedpostData/727553/T1w/Diffusion.bedpostX/merged --seed=seeds.txt --steplength=0.500
# 180824-17:50:56,10 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 404 jobs ready. Free memory (GB): 169.78/169.98, Free processors: 0/1.
#                      Currently running:
#                        * runpbx2_gpu_dtispace.pbx2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-c21c56c03ade> in <module>()
#      17 #runpbx2.write_graph()
#      18
# ---> 19 runpbx2.run(plugin='MultiProc', plugin_args={'n_procs' : 1})
#
# /usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/workflows.pyc in run(self, plugin, plugin_args, updatehash)
#     593         if str2bool(self.config['execution']['create_report']):
#     594             self._write_report_info(self.base_dir, self.name, execgraph)
# --> 595         runner.run(execgraph, updatehash=updatehash, config=self.config)
#     596         datestr = datetime.utcnow().strftime('%Y%m%dT%H%M%S')
#     597         if str2bool(self.config['execution']['write_provenance']):
#
# /usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/base.pyc in run(self, graph, config, updatehash)
#     134             # https://github.com/nipy/nipype/pull/2200#discussion_r141605722
#     135             jobs_ready = np.nonzero(~self.proc_done &
# --> 136                                     (self.depidx.sum(0) == 0))[1]
#     137
#     138             progress_stats = (len(self.proc_done),
#
# /usr/local/lib/python2.7/dist-packages/scipy/sparse/base.pyc in sum(self, axis, dtype, out)
#    1009             # sum over columns
#    1010             ret = np.asmatrix(np.ones(
# -> 1011                 (1, m), dtype=res_dtype)) * self
#    1012         else:
#    1013             # sum over rows
#
# /usr/local/lib/python2.7/dist-packages/scipy/sparse/base.pyc in __rmul__(self, other)
#     547             except AttributeError:
#     548                 tr = np.asarray(other).transpose()
# --> 549             return (self.transpose() * tr).transpose()
#     550
#     551     #####################################
#
# /usr/local/lib/python2.7/dist-packages/scipy/sparse/lil.pyc in transpose(self, axes, copy)
#     456
#     457     def transpose(self, axes=None, copy=False):
# --> 458         return self.tocsr(copy=copy).transpose(axes=axes, copy=False).tolil(copy=False)
#     459
#     460     transpose.__doc__ = spmatrix.transpose.__doc__
#
# /usr/local/lib/python2.7/dist-packages/scipy/sparse/lil.pyc in tocsr(self, copy)
#     474         indptr = np.cumsum([0] + lst, dtype=idx_dtype)
#     475         indices = np.array([x for y in self.rows for x in y], dtype=idx_dtype)
# --> 476         data = np.array([x for y in self.data for x in y], dtype=self.dtype)
#     477
#     478         from .csr import csr_matrix
#
# KeyboardInterrupt:

# %%
pbx2.interface.cmd = "probtrackx2_gpu"

# %%
! ls probtrackx2_gpu

# %%
### Each probtrackx command for the HCP data set was using about 2% of the memory.. it varied from 1.4 --> 2.3

### So on this machine, we could probably specify 36 threads... even 40 although that may start getting dicey

# %%
### Write a data validator that makes sure everything in the datasource actually exists...

# %% [markdown]
# [Mandatory]
# fsamples: (a list of items which are an existing file name)
# mask: (an existing file name)
#         bet binary mask file in diffusion space
#         flag: -m %s
# phsamples: (a list of items which are an existing file name)
# seed: (an existing file name or a list of items which are an existing
#          file name or a list of items which are a list of from 3 to 3 items
#          which are an integer (int or long))
#         seed volume(s), or voxel(s)or freesurfer label file
#         flag: --seed=%s
# thsamples: (a list of items which are an existing file name)
#
# [Optional]
# args: (a string)
#         Additional parameters to the command
#         flag: %s
# avoid_mp: (an existing file name)
#         reject pathways passing through locations given by this mask
#         flag: --avoid=%s
# c_thresh: (a float)
#         curvature threshold - default=0.2
#         flag: --cthr=%.3f
# colmask4: (an existing file name)
#         Mask for columns of matrix4 (default=seed mask)
#         flag: --colmask4=%s
# correct_path_distribution: (a boolean)
#         correct path distribution for the length of the pathways
#         flag: --pd
# dist_thresh: (a float)
#         discards samples shorter than this threshold (in mm - default=0)
#         flag: --distthresh=%.3f
# distthresh1: (a float)
#         Discards samples (in matrix1) shorter than this threshold (in mm -
#         default=0)
#         flag: --distthresh1=%.3f
# distthresh3: (a float)
#         Discards samples (in matrix3) shorter than this threshold (in mm -
#         default=0)
#         flag: --distthresh3=%.3f
# environ: (a dictionary with keys which are a value of type 'str' and
#          with values which are a value of type 'str', nipype default value:
#          {})
#         Environment variables
# fibst: (an integer (int or long))
#         force a starting fibre for tracking - default=1, i.e. first fibre
#         orientation. Only works if randfib==0
#         flag: --fibst=%d
# fopd: (an existing file name)
#         Other mask for binning tract distribution
#         flag: --fopd=%s
# force_dir: (a boolean, nipype default value: True)
#         use the actual directory name given - i.e. do not add + to make a
#         new directory
#         flag: --forcedir
# ignore_exception: (a boolean, nipype default value: False)
#         Print an error message instead of throwing an exception in case the
#         interface fails to run
# inv_xfm: (a file name)
#         transformation matrix taking DTI space to seed space (compulsory
#         when using a warp_field for seeds_to_dti)
#         flag: --invxfm=%s
# loop_check: (a boolean)
#         perform loop_checks on paths - slower, but allows lower curvature
#         threshold
#         flag: --loopcheck
# lrtarget3: (an existing file name)
#         Column-space mask used for Nxn connectivity matrix
#         flag: --lrtarget3=%s
# meshspace: ('caret' or 'freesurfer' or 'first' or 'vox')
#         Mesh reference space - either "caret" (default) or "freesurfer" or
#         "first" or "vox"
#         flag: --meshspace=%s
# mod_euler: (a boolean)
#         use modified euler streamlining
#         flag: --modeuler
# n_samples: (an integer (int or long), nipype default value: 5000)
#         number of samples - default=5000
#         flag: --nsamples=%d
# n_steps: (an integer (int or long))
#         number of steps per sample - default=2000
#         flag: --nsteps=%d
# network: (a boolean)
#         activate network mode - only keep paths going through at least one
#         seed mask (required if multiple seed masks)
#         flag: --network
# omatrix1: (a boolean)
#         Output matrix1 - SeedToSeed Connectivity
#         flag: --omatrix1
# omatrix2: (a boolean)
#         Output matrix2 - SeedToLowResMask
#         flag: --omatrix2
#         requires: target2
# omatrix3: (a boolean)
#         Output matrix3 (NxN connectivity matrix)
#         flag: --omatrix3
#         requires: target3, lrtarget3
# omatrix4: (a boolean)
#         Output matrix4 - DtiMaskToSeed (special Oxford Sparse Format)
#         flag: --omatrix4
# onewaycondition: (a boolean)
#         Apply waypoint conditions to each half tract separately
#         flag: --onewaycondition
# opd: (a boolean, nipype default value: True)
#         outputs path distributions
#         flag: --opd
# os2t: (a boolean)
#         Outputs seeds to targets
#         flag: --os2t
# out_dir: (an existing directory name)
#         directory to put the final volumes in
#         flag: --dir=%s
# output_type: ('NIFTI_PAIR' or 'NIFTI_PAIR_GZ' or 'NIFTI_GZ' or
#          'NIFTI')
#         FSL output type
# rand_fib: (0 or 1 or 2 or 3)
#         options: 0 - default, 1 - to randomly sample initial fibres (with f
#         > fibthresh), 2 - to sample in proportion fibres (with f>fibthresh)
#         to f, 3 - to sample ALL populations at random (even if f<fibthresh)
#         flag: --randfib=%d
# random_seed: (a boolean)
#         random seed
#         flag: --rseed
# s2tastext: (a boolean)
#         output seed-to-target counts as a text file (useful when seeding
#         from a mesh)
#         flag: --s2tastext
# sample_random_points: (a boolean)
#         sample random points within seed voxels
#         flag: --sampvox
# samples_base_name: (a string, nipype default value: merged)
#         the rootname/base_name for samples files
#         flag: --samples=%s
# seed_ref: (an existing file name)
#         reference vol to define seed space in simple mode - diffusion space
#         assumed if absent
#         flag: --seedref=%s
# simple: (a boolean)
#         rack from a list of voxels (seed must be a ASCII list of
#         coordinates)
#         flag: --simple
# step_length: (a float)
#         step_length in mm - default=0.5
#         flag: --steplength=%.3f
# stop_mask: (an existing file name)
#         stop tracking at locations given by this mask file
#         flag: --stop=%s
# target2: (an existing file name)
#         Low resolution binary brain mask for storing connectivity
#         distribution in matrix2 mode
#         flag: --target2=%s
# target3: (an existing file name)
#         Mask used for NxN connectivity matrix (or Nxn if lrtarget3 is set)
#         flag: --target3=%s
# target4: (an existing file name)
#         Brain mask in DTI space
#         flag: --target4=%s
# target_masks: (a list of items which are a file name)
#         list of target masks - required for seeds_to_targets classification
#         flag: --targetmasks=%s
# terminal_output: ('stream' or 'allatonce' or 'file' or 'none')
#         Control terminal output: `stream` - displays to terminal immediately
#         (default), `allatonce` - waits till command is finished to display
#         output, `file` - writes output to file, `none` - output is ignored
# use_anisotropy: (a boolean)
#         use anisotropy to constrain tracking
#         flag: --usef
# verbose: (0 or 1 or 2)
#         Verbose level, [0-2].Level 2 is required to output particle files.
#         flag: --verbose=%d
# waycond: ('OR' or 'AND')
#         Waypoint condition. Either "AND" (default) or "OR"
#         flag: --waycond=%s
# wayorder: (a boolean)
#         Reject streamlines that do not hit waypoints in given order. Only
#         valid if waycond=AND
#         flag: --wayorder
# waypoints: (an existing file name)
#         waypoint mask or ascii list of waypoint masks - only keep paths
#         going through ALL the masks
#         flag: --waypoints=%s
# xfm: (an existing file name)
#         transformation matrix taking seed space to DTI space (either FLIRT
#         matrix or FNIRT warp_field) - default is identity
#         flag: --xfm=%s

# %%
# runpbx2.connect( dti_datasource, ('thsamples',samples_base_name_fxn) ,pbx2,'samples_base_name')
# # Run tractography with warp to/from template space
# $statement .= " -s $WORKINGDATAPATH/Fox_" . $subj[$k] . "/data.bedpostX/merged "; 
# $statement .= " -x $WORKINGDATAPATH/All_Foxes_FA_to_Unselected-Template_WM.nii.gz ";  ## check downsample
# $statement .= " -l   --fibthresh=0.1 --randfib=0 ";  ## check # of samples
# $statement .= " --forcedir --opd ";
# $statement .= " --dir=$WORKINGDATAPATH/Fox_" . $subj[$k] . "/data.bedpostX/WholeBrainMatrixConnectivity_TemplateSpace_fullres/ ";
# print "$statement \n";

# %%
# --pd   correct_path_distribution 
#-l
#-c 0.2    --->> c_thresh
#-S 2000   
#--steplength=0.5
#-P 5000    n_samples
#--fibthresh=0.1   
#--randfib=0  rand_fib
#-s /home/ehecht/TEMPLETON/Templeton_DTI_Analysis/Data/Subj_026/data.bedpostX/merged 
#-m /home/ehecht/TEMPLETON/Templeton_DTI_Analysis/Data/Subj_026/data/nodif_brain_mask.nii.gz
#-x /home/ehecht/TEMPLETON/Templeton_DTI_Analysis/Data/ROIs/Human_BasalForebrain_Left.nii.gz 
#--target2=/home/ehecht/TEMPLETON/Templeton_DTI_Analysis/Data/ROIs/MNI152_T1_1mm_brain_mask.nii.gz 
#--xfm=/home/ehecht/TEMPLETON/Templeton_Registration/xfms/Subj_026_Scan2_MNI_fnirt_struct_6dof-flirt_nodif.nii.gz
#--invxfm=/home/ehecht/TEMPLETON/Templeton_Registration/xfms/Subj_026_Scan2_nodif_6dof-flirt_struct_fnirt_MNI.nii.gz 
#--forcedir 
#--opd
#--dir=/home/ehecht/TEMPLETON/Templeton_DTI_Analysis/Data/Subj_026/BasalForebrain_Left_TemplateSpace/

# %%
#  pbx2.inputs.seed = 'seed_source.nii.gz'
# >>> pbx2.inputs.thsamples = 'merged_th1samples.nii.gz'
# >>> pbx2.inputs.fsamples = 'merged_f1samples.nii.gz'
# >>> pbx2.inputs.phsamples = 'merged_ph1samples.nii.gz'
# >>> pbx2.inputs.mask = 'nodif_brain_mask.nii.gz'
# >>> pbx2.inputs.out_dir = '.'
# >>> pbx2.inputs.n_samples = 3
# >>> pbx2.inputs.n_steps = 10
# >>> pbx2.cmdline

# datasource.inputs.template = '%s/T1w/Diffusion/%s'
# datasource.inputs.template_args = dict(dwi=[['subject_id', 'data.nii.gz']],
#                                        bvecs=[['subject_id', 'bvecs']],
#                                        bvals=[['subject_id', 'bvals']],
#                                        nodif_brain_mask=[['subject_id','nodif_brain_mask.nii.gz']])
## Just mapped each subject to the corresponding bvec,bvals, brain mask and preprocessed DWI data
### Create the Node for DTIFIT
# dtifit = pe.Node(interface=fsl.DTIFit(), name='dtifit')


# gen_fa = pe.Workflow(name="gen_fa")
# gen_fa.base_dir = '/data/HCP_Data/NipypeScratch/'
# gen_fa.connect(subject_id_infosource, 'subject_id', datasource, 'subject_id')

# gen_fa.connect(subject_id_infosource, 'subject_id', dtifit, 'base_name')
# gen_fa.connect(datasource, 'bvecs', dtifit, 'bvecs')
# gen_fa.connect(datasource, 'bvals', dtifit, 'bvals')
# gen_fa.connect(datasource, 'nodif_brain_mask', dtifit, 'mask')
# gen_fa.connect(datasource, 'dwi', dtifit, 'dwi')

# %%
print(gen_fa.write_graph(graph2use='colored',simple_form=False))
Image('/data/HCP_Data/NipypeScratch/gen_fa/graph.png')
#Image('/data/HCP_Data/NipypeScratch/gen_fa/graph.png')

# %%
gen_fa.run(plugin='MultiProc', plugin_args={'n_procs' : 20})

# %%
#!ls /data/HCP_Data/HCP_BedpostData/106016/T1w/Diffusion/

# %%
datasink = pe.Node(interface=nio.DataSink(), name="datasink")
datasink.inputs.base_directory = os.path.join(os.path.abspath(working_data_dir),
                                              'sri_results')
datasink.inputs.parameterization = False
gen_fa.connect(dtifit, 'FA', datasink, 'FA')
gen_fa.connect(dtifit, 'MD', datasink, 'MD')

# %%
from nipype.interfaces import fsl

subjDir = "/data/HCP_Data/HCP_BedpostData/100206/T1w/Diffusion.bedpostX/"

pbx2 = fsl.ProbTrackX2()
pbx2.inputs.seed = '/data/HCP_Data/EHECHT_ROIS/Human_BasalForebrain_Left.nii.gz'
pbx2.inputs.thsamples = subjDir + 'merged_th1samples.nii.gz'
pbx2.inputs.fsamples =  subjDir + 'merged_f1samples.nii.gz'
pbx2.inputs.phsamples =  subjDir + 'merged_ph1samples.nii.gz'
pbx2.inputs.mask =  subjDir + 'nodif_brain_mask.nii.gz'
pbx2.inputs.out_dir = '.'
pbx2.inputs.n_samples = 3
pbx2.inputs.n_steps = 10
pbx2.cmdline
pbx2.run()
#'probtrackx2 --forcedir -m nodif_brain_mask.nii.gz --nsamples=3 --nstep
